# %%
# Given a list of floats, plot it considering it as Y and X as a range(len(Y))

import matplotlib.pyplot as plt
import numpy as np
import json

# %%
data = json.load(open("/home/mpf/code/kaggle/llm-prompt/src/optimization/mean_prompt_all_words.json"))
y = [dct["score"] for dct in data]

plt.xticks(np.arange(0, len(y), 5.0))
plt.plot(range(len(y)), y)

# %%
data = json.load(open("/home/mpf/code/kaggle/llm-prompt/src/optimization/mean_prompt_sel_words.json"))
y = [dct["score"] for dct in data]

plt.plot(range(len(y)), y)
